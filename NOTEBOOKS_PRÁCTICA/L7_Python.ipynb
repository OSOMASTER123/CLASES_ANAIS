# %% [markdown]
# # 1ING09 - Digital Signal Processing
# # Laboratory 9: Filter Design (IIR VS FIR)
#
# Student:
#
# Code:

# %%
### Here import your libraries and functions

# %% [markdown]
# ## Star Wars V: Luke Skywalker's mioelectric hand prosthesis
# In the movie, "Star Wars V: the empire Strike Back", Luke Skywalker loses his hand after a fight against
# Darth Vader. In the end, he eventually gets a myoelectric prosthesis capable of recognizing his neuromuscular
# gestures. A long time ago in a galaxy far far away, Electromiography spectral information is found between
# [70,245] Hz.
# You manage to obtain a sample of the contraction of the "flexor digitorum superficialis muscle" in Luke
# Skywalker's prosthesis. However, the sample is contaminated with noise around 20Hz due to the fighting, and
# more noise around 400Hz due to the high levels of Midi-chlorian in Luke.

# %% [markdown]
# ### 1) Load the signal
# Load the signal "luke.mat" where you will find the emg original signal and the corrupted one; together with its
# sampling frequency and time vector. Show both signals in the time and spectral domain (magnitude and phase
# in Hz). (1 pt)

# %% [markdown]
# ### 2) Design of IIR filter
# In order to extract the spectral information, you are requested to filter the signal with a bandpass filter. However,
# you find that at low frequencies you requiere less attenuation than in high frequencies. Then, you decide to
# create independent low-pass and high-pass filters.

# %% [markdown]
# #### 2a) Design of the Highpass filter
# Design a high-pass digital filter with the following requirements: (2.5 pts)
#
# $$
# H_1\left(e^{j w}\right)= \begin{cases}0 \leq\left|H\left(e^{j w}\right)\right| \leq 0.56234 & |f| \leq 60 \mathrm{~Hz} \\ 0.89125 \leq\left|H\left(e^{j w}\right)\right| \leq 1 & 75 \mathrm{~Hz} \leq|f|\end{cases}
# $$
#
# Hint1: round the magnitud after converting to decibels.
# Hint2: Use 1000 samples for freqz function and work in Hz.

# %% [markdown]
# #### 2b) Design of Lowpass filter
# Design a low-pass digital filter with the following requirements: (2.5 pts)
#
# $$
# H_1\left(e^{\mathrm{jw}}\right)= \begin{cases}0.89125 \leq\left|H\left(e^{\mathrm{jw}}\right)\right| \leq 1 & |f| \leq 240 \mathrm{~Hz} \\ 0 \leq\left|H\left(e^{\mathrm{jw}}\right)\right| \leq 0.1 & 250 \mathrm{~Hz} \leq|f|\end{cases}
# $$
#
# Hint: Use the same aforementioned hints.

# %% [markdown]
# #### 2c) Integration of filters
# Show the integration of both filters in order to get a bandpass filter. From 0 to 500 Hz, plot the magnitude, the
# unwraped phase and the magnitude in dB. Analyze the results. (2 pts)

# %% [markdown]
# ### 3) Design of FIR filters
# Design a band-pass digital filter with the following requirements:
#
# $$
# H_1\left(e^{j w}\right)= \begin{cases}0 \leq\left|H\left(e^{j w}\right)\right| \leq 0.56234 & |f| \leq 60 \mathrm{~Hz} \\ 0.89125 \leq\left|H\left(e^{j w}\right)\right| \leq 1 & 75 \mathrm{~Hz} \leq|f|\end{cases}
# $$ (2 pts)
#
# $$
# H_2\left(e^{j w}\right)= \begin{cases}0.89125 \leq\left|H\left(e^{j w}\right)\right| \leq 1 & |f| \leq 240 \mathrm{~Hz} \\ 0 \leq\left|H\left(e^{j w}\right)\right| \leq 0.1 & 250 \mathrm{~Hz} \leq|f|\end{cases}
# $$ (2 pts)
#
# Use the function "fir2" to generate a lowpass and a highpass filter with a blackman window. Then, integrate
# them into one. From 0 to 500 Hz, plot the magnitude, the unwraped phase and the magnitude in dB.
# Consider only 8 samples for magnitude and frequency in "fir2".

# %% [markdown]
# ### 4) Previous comparation (IIR VS FIR)
# Perform a comparative analysis between IIR and FIR in magnitude, phase. Justifify theoretically you comments.
#
# 1. In one figure, compare the magnitude of the filters. (1 pt)

# %% [markdown]
# 2. In one figure, compare the phase of the filters. (1 pt)

# %% [markdown]
# 3. In one figure, compare the magnitude in dB of the filters. (1 pt)

# %% [markdown]
# ### 5) Filtering
# Filter the signal by both methods (FIR and IIR).
#
# #### 5a) Filtering by FIR
# Hint: Use "conv" function to filter the corrupted emg signal. (1.5 pts)

# %% [markdown]
# #### 5b) Filtering by IIR
# Hint: Use the "filter" function to filter the corrupted emg signal. (1.5 pts)

# %% [markdown]
# ### 6) Compare with the original
# Compare in magnitude and phase the original signal with the filtered ones (FIR and IIR). Analyze the results. (2
# pts)
